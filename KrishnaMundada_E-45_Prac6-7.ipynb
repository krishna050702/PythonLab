# %% [markdown]
# ## Name: Krishna Mundada
# ## Batch: E3
# ## Roll no:- 45
# ## Topic :- Practical number 06 & 07 [Pandas,MatplotLib, Seborn], Basic analysis of Automobile dataset

# %% [markdown]
# ## ------------------------------------------------

# %% [markdown]
# ### Q1. Load the Automobiledata from a given csv file into a dataframe and print the shape of the data, type of the data and first and last 4 rows (Automobile_data.csv)

# %% [markdown]
# ### Q2. Replace the abnormal symbols i.e. ?? , ## to null value i.e. NaN

# %% [markdown]
# ### Q3. Describe the dataset, and find number of observations, missing values and nan values.

# %% [markdown]
# ### Q4. View basic statistical details like percentile, mean, std deviation, mode, variance, skewness and kutosis of Automobile data

# %% [markdown]
# ### Q5. Find the most expensive car company name

# %% [markdown]
# ### Q6. Print all Toyata cars available

# %% [markdown]
# ### Q7. Find each company’s highest price car

# %% [markdown]
# ### Q8. Find the average mileage of each car making company

# %% [markdown]
# ### Q9. Sort all cars by price column

# %% [markdown]
# ### Q10. Create the horrizontalbarplot for Automobiledataset

# %% [markdown]
# ### Q11. Create a pair plot.

# %% [markdown]
# ### Q12. Print correlation matrix for this Automobiledataset and show heatmap.

# %% [markdown]
# ## ----------------------------------------------------------

# %%
import pandas as pd

# %%
auto = pd.read_csv('Automobile_data.csv')

# %%
auto.shape
# Out:
# (205, 26)

# %%
type(auto)
# Out:
# pandas.core.frame.DataFrame

# %%
auto.head(4)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
auto.tail(4)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 201         mpfi  3.78    3.15               8.7        160      5300
# 202         mpfi  3.58    2.87               8.8        134      5500
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
auto.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
auto.replace("##",0)
auto.replace('NaN',0)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
auto.std()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\2654375206.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   auto.std()
# symboling              1.245307
# wheel-base             6.021776
# length                12.337289
# width                  2.145204
# height                 2.443522
# curb-weight          520.680204
# engine-size           41.642693
# compression-ratio      3.972040
# city-mpg               6.542142
# highway-mpg            6.886443
# dtype: float64

# %%
auto.mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\2601072796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   auto.mean()
# symboling               0.834146
# wheel-base             98.756585
# length                174.049268
# width                  65.907805
# height                 53.724878
# curb-weight          2555.565854
# engine-size           126.907317
# compression-ratio      10.142537
# city-mpg               25.219512
# highway-mpg            30.751220
# dtype: float64

# %%
auto.mode()
# Out:
#    symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 0        0.0                 ?  toyota       gas        std         four
# 1        NaN               NaN     NaN       NaN        NaN          NaN
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0      sedan          fwd           front        94.5  ...           92
# 1        NaN          NaN             NaN         NaN  ...          122
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.62     3.4               9.0         68      5500     31.0
# 1          NaN   NaN     NaN               NaN        NaN       NaN      NaN
#
#   highway-mpg price
# 0        25.0     ?
# 1         NaN   NaN
#
# [2 rows x 26 columns]

# %%
auto.rank(pct=True)
# Out:
#      symboling  normalized-losses      make  fuel-type  aspiration  \
# 0     0.936585           0.902439  0.009756    0.55122    0.412195
# 1     0.936585           0.902439  0.009756    0.55122    0.412195
# 2     0.582927           0.902439  0.009756    0.55122    0.412195
# 3     0.792683           0.475610  0.034146    0.55122    0.412195
# 4     0.792683           0.475610  0.034146    0.55122    0.412195
# ..         ...                ...       ...        ...         ...
# 200   0.070732           0.785366  0.975610    0.55122    0.412195
# 201   0.070732           0.785366  0.975610    0.55122    0.912195
# 202   0.070732           0.785366  0.975610    0.55122    0.412195
# 203   0.070732           0.785366  0.975610    0.05122    0.912195
# 204   0.070732           0.785366  0.975610    0.55122    0.912195
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0        0.785366    0.017073      0.817073         0.495122    0.021951  ...
# ...

# %%
auto.var()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\3637308487.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   auto.var()
# symboling                 1.550789
# wheel-base               36.261782
# length                  152.208688
# width                     4.601900
# height                    5.970800
# curb-weight          271107.874319
# engine-size            1734.113917
# compression-ratio        15.777104
# city-mpg                 42.799617
# highway-mpg              47.423099
# dtype: float64

# %%
auto.skew(axis=1)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\2648977082.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   auto.skew(axis=1)
# 0      3.134908
# 1      3.134908
# 2      3.136050
# 3      3.130289
# 4      3.136652
#          ...
# 200    3.136083
# 201    3.137228
# 202    3.132206
# 203    3.140939
# 204    3.137510
# Length: 205, dtype: float64

# %%
auto.kurtosis()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\1227403792.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   auto.kurtosis()
# symboling           -0.676271
# wheel-base           1.017039
# length              -0.082895
# width                0.702764
# height              -0.443812
# curb-weight         -0.042854
# engine-size          5.305682
# compression-ratio    5.233054
# city-mpg             0.578648
# highway-mpg          0.440070
# dtype: float64

# %%
automax = auto [['make','price']][auto.price==auto['price'].max()]
automax
# Out:
#         make price
# 9       audi     ?
# 44     isuzu     ?
# 45     isuzu     ?
# 129  porsche     ?

# %%
car_Manufacturers = auto.groupby('make')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 150          1                87  toyota       gas        std          two
# 151          1                87  toyota       gas        std          two
# 152          1                74  toyota       gas        std         four
# 153          0                77  toyota       gas        std         four
# 154          0                81  toyota       gas        std         four
# 155          0                91  toyota       gas        std         four
# 156          0                91  toyota       gas        std         four
# 157          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 159          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# ...

# %%
car_Manufacturers = auto.groupby('make')
priceDf = car_Manufacturers['make','price'].max()
priceDf
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\1319487044.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = car_Manufacturers['make','price'].max()
#                         make  price
# make
# alfa-romero      alfa-romero  16500
# audi                    audi      ?
# bmw                      bmw  41315
# chevrolet          chevrolet   6575
# dodge                  dodge   8921
# honda                  honda   9095
# isuzu                  isuzu      ?
# jaguar                jaguar  36000
# mazda                  mazda   8845
# mercedes-benz  mercedes-benz  45400
# mercury              mercury  16503
# mitsubishi        mitsubishi   9959
# nissan                nissan   9549
# peugot                peugot  18150
# plymouth            plymouth   8921
# porsche              porsche      ?
# renault              renault   9895
# saab                    saab  18620
# ...

# %%
car_Manufacturers = auto.groupby('make')
mileageDf = car_Manufacturers['make','highway-mpg'].mean()
mileageDf
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22400\3831644592.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mileageDf = car_Manufacturers['make','highway-mpg'].mean()
#                highway-mpg
# make
# alfa-romero      26.666667
# audi             24.142857
# bmw              25.375000
# chevrolet        46.333333
# dodge            34.111111
# honda            35.461538
# isuzu            36.000000
# jaguar           18.333333
# mazda            31.941176
# mercedes-benz    21.000000
# mercury          24.000000
# mitsubishi       31.153846
# nissan           32.944444
# peugot           26.636364
# plymouth         34.142857
# porsche          26.000000
# renault          31.000000
# saab             27.333333
# subaru           30.750000
# toyota           32.906250
# volkswagen       34.916667
# volvo            25.818182

# %%
carsort = auto.sort_values(by=['price', 'horsepower'], ascending=False)
carsort.head(5)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 44           1                 ?       isuzu       gas        std
# 45           0                 ?       isuzu       gas        std
# 129          1                 ?     porsche       gas        std
# 9            0                 ?        audi       gas      turbo
# 188          2                94  volkswagen       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 44           two      sedan          fwd           front        94.5  ...
# 45          four      sedan          fwd           front        94.5  ...
# 129          two  hatchback          rwd           front        98.4  ...
# 9            two  hatchback          4wd           front        99.5  ...
# 188         four      sedan          fwd           front        97.3  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(auto.make,auto.price)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(auto.make,auto.price)
plt.subplot(1,2,2)
plt.plot(auto.make,auto["highway-mpg"])

# %%
auto.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178515 -0.035823
# ...

# %%
auto.style.background_gradient(cmap ='viridis')\
 .set_properties(**{'font-size': '20px'})
# Out:
# <style type="text/css">
# #T_1f596_row0_col0, #T_1f596_row1_col0, #T_1f596_row28_col12, #T_1f596_row29_col0, #T_1f596_row30_col23, #T_1f596_row30_col24, #T_1f596_row47_col13, #T_1f596_row48_col13, #T_1f596_row49_col16, #T_1f596_row55_col0, #T_1f596_row56_col0, #T_1f596_row57_col0, #T_1f596_row58_col0, #T_1f596_row72_col0, #T_1f596_row73_col9, #T_1f596_row73_col10, #T_1f596_row80_col0, #T_1f596_row81_col0, #T_1f596_row82_col0, #T_1f596_row83_col0, #T_1f596_row84_col0, #T_1f596_row104_col0, #T_1f596_row105_col0, #T_1f596_row123_col12, #T_1f596_row124_col0, #T_1f596_row125_col0, #T_1f596_row126_col0, #T_1f596_row127_col0, #T_1f596_row128_col0, #T_1f596_row129_col11, #T_1f596_row132_col0, #T_1f596_row134_col0, #T_1f596_row136_col0, #T_1f596_row178_col0, #T_1f596_row179_col0, #T_1f596_row182_col20, #T_1f596_row184_col20, #T_1f596_row187_col20, #T_1f596_row189_col0, #T_1f596_row190_col0, #T_1f596_row192_col20, #T_1f596_row203_col20 {
#   background-color: #fde725;
#   color: #000000;
# ...
